# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# MOVED ALL IMPORTS TO THE TOP

# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
from newsapi import NewsApiClient
from pathlib import Path

# For Sentiment Analysis
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
# %matplotlib inline

# For Tokenizing
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

# For NER
import spacy
from spacy import displacy

# For Ngrams
from collections import Counter
from nltk import ngrams
from nltk.util import ngrams

# For Word Clouds
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\piercerachel\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\piercerachel\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\piercerachel\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\piercerachel\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Read your api key environment variable
load_dotenv()

api_key = os.getenv("NEWS_API")

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
bitcoin_news = newsapi.get_everything(
    q="bitcoin",
    language="en"
)

# Show the total number of news
bitcoin_news["totalResults"]
# Out:
# 8025

# %%
# Fetch the Ethereum news articles
ethereum_news = newsapi.get_everything(
    q="ethereum",
    language="en"
)

# Show the total number of news
ethereum_news["totalResults"]
# Out:
# 3392

# %%
# Create the Bitcoin sentiment scores DataFrame
def create_df(news, language):
    articles = []
    for article in news:
        try:
            title = article["title"]
            description = article["description"]
            text = article["content"]
            date = article["publishedAt"][:10]

            articles.append({
                "title": title,
                "description": description,
                "text": text,
                "date": date,
                "language": language
            })
        except AttributeError:
            pass

    return pd.DataFrame(articles)

# %%
# Create the Bitcoin sentiment scores DataFrame
bitcoin_df = create_df(bitcoin_news["articles"], "en")
bitcoin_df.head()
# Out:
#                                                title  \
# 0  Why New York State Is Experiencing a Bitcoin Boom
# 1  Nothing's 'Black Edition' brings a modern touc...
# 2  Explainer: What we know so far about El Salvad...
# 3                        AMC Begins Accepting Crypto
# 4         El Salvador plans 'Bitcoin City' - Reuters
#
#                                          description  \
# 0  Cryptocurrency miners are flocking to New York...
# 1  Earlier this year, Nothing released a pair of ...
# 2  El Salvador plans to build the world's first <...
# 3  Bitcoin, Ethereum, Bitcoin Cash and Litecoin a...
# 4  After becoming the first country to accept the...
#
#                                                 text        date language
# 0  The plant opening northeast of Niagara Falls t...  2021-12-06       en
# 1  Earlier this year, Nothing released a pair of ...  2021-12-01       en
# 2  MIZATA, El Salvador/LONDON, Nov 22 (Reuters) -...  2021-11-22       en
# 3  In keeping with a previous announcement, AMC t...  2021-11-12       en
# 4  Posted \r\nAfter becoming the first country to...  2021-11-22       en

# %%
# Create the Ethereum sentiment scores DataFrame
ethereum_df = create_df(ethereum_news["articles"], "en")
ethereum_df.head()
# Out:
#                                                title  \
# 0  The NFT Bay asks if you would steal all the JPEGs
# 1  Almost buying a copy of the Constitution is ea...
# 2                        AMC Begins Accepting Crypto
# 3    What’s Ethereum and Is It Worth the Investment?
# 4  A Software Bug Let Hackers Drain $31M From a C...
#
#                                          description  \
# 0  The NFT Bay is an incredible piece of performa...
# 1  ConstitutionDAO has refunded more than half of...
# 2  Bitcoin, Ethereum, Bitcoin Cash and Litecoin a...
# 3  Ethereum has been on a tear this year. It’s ou...
# 4  An attacker exploited a vulnerability in MonoX...
#
#                                                 text        date language
# 0  If you claim ownership, someone will probably ...  2021-11-19       en
# 1  More than $1.2 million has already been spent ...  2021-11-24       en
# 2  In keeping with a previous announcement, AMC t...  2021-11-12       en
# 3  Ethereum has been on a tear this year. Its out...  2021-11-23       en
# 4  Blockchain startup MonoX Finance said on Wedne...  2021-12-02       en

# %%
# Describe the Bitcoin Sentiment
# First I need to get the sentiment calculation
def get_sentiment(score):
    """
    Calculates the sentiment based on the compound score.
    """
    result = 0  # Neutral by default
    if score >= 0.05:  # Positive
        result = 1
    elif score <= -0.05:  # Negative
        result = -1

    return result

# %%
# Second I need the Sentiment scores dictionaries
title_sent = {
    "title_compound": [],
    "title_pos": [],
    "title_neu": [],
    "title_neg": [],
    "title_sent": [],
}
text_sent = {
    "text_compound": [],
    "text_pos": [],
    "text_neu": [],
    "text_neg": [],
    "text_sent": [],
}

# Get sentiment for the text and the title
for index, row in bitcoin_df.iterrows():
    try:
        # Sentiment scoring with VADER
        title_sentiment = analyzer.polarity_scores(row["title"])
        title_sent["title_compound"].append(title_sentiment["compound"])
        title_sent["title_pos"].append(title_sentiment["pos"])
        title_sent["title_neu"].append(title_sentiment["neu"])
        title_sent["title_neg"].append(title_sentiment["neg"])
        title_sent["title_sent"].append(get_sentiment(title_sentiment["compound"]))

        text_sentiment = analyzer.polarity_scores(row["text"])
        text_sent["text_compound"].append(text_sentiment["compound"])
        text_sent["text_pos"].append(text_sentiment["pos"])
        text_sent["text_neu"].append(text_sentiment["neu"])
        text_sent["text_neg"].append(text_sentiment["neg"])
        text_sent["text_sent"].append(get_sentiment(text_sentiment["compound"]))
    except AttributeError:
        pass

# Attaching sentiment columns to the Bitcoin DataFrame
title_sentiment_df = pd.DataFrame(title_sent)
text_sentiment_df = pd.DataFrame(text_sent)
bitcoin_df = bitcoin_df.join(title_sentiment_df).join(text_sentiment_df)

bitcoin_df.head()
# Out:
#                                                title  \
# 0  Why New York State Is Experiencing a Bitcoin Boom
# 1  Nothing's 'Black Edition' brings a modern touc...
# 2  Explainer: What we know so far about El Salvad...
# 3                        AMC Begins Accepting Crypto
# 4         El Salvador plans 'Bitcoin City' - Reuters
#
#                                          description  \
# 0  Cryptocurrency miners are flocking to New York...
# 1  Earlier this year, Nothing released a pair of ...
# 2  El Salvador plans to build the world's first <...
# 3  Bitcoin, Ethereum, Bitcoin Cash and Litecoin a...
# 4  After becoming the first country to accept the...
#
#                                                 text        date language  \
# 0  The plant opening northeast of Niagara Falls t...  2021-12-06       en
# 1  Earlier this year, Nothing released a pair of ...  2021-12-01       en
# 2  MIZATA, El Salvador/LONDON, Nov 22 (Reuters) -...  2021-11-22       en
# 3  In keeping with a previous announcement, AMC t...  2021-11-12       en
# 4  Posted \r\nAfter becoming the first country to...  2021-11-22       en
#
#    title_compound  title_pos  title_neu  title_neg  title_sent  text_compound  \
# 0          0.0000      0.000      1.000      0.000           0         0.0000
# 1         -0.1027      0.000      0.877      0.123          -1         0.5106
# 2          0.0000      0.000      1.000      0.000           0         0.0000
# 3          0.3818      0.464      0.536      0.000           1         0.5719
# 4          0.0000      0.000      1.000      0.000           0         0.4767
#
#    text_pos  text_neu  text_neg  text_sent
# 0     0.000     1.000       0.0          0
# 1     0.099     0.901       0.0          1
# 2     0.000     1.000       0.0          0
# 3     0.153     0.847       0.0          1
# 4     0.136     0.864       0.0          1

# %%
# Now to analyze the results:
bitcoin_df.plot(
    y=["title_sent", "text_sent"],
    kind="bar",
    title="News Title and Text Sentiment Comparison",
    figsize=(10, 8),
    grid=True,
)
# Out:
# <AxesSubplot:title={'center':'News Title and Text Sentiment Comparison'}>

# %%
bitcoin_df.describe()
# Out:
#        title_compound  title_pos  title_neu  title_neg  title_sent  \
# count       20.000000  20.000000  20.000000  20.000000   20.000000
# mean         0.008820   0.023200   0.964500   0.012300   -0.050000
# std          0.093277   0.103754   0.107691   0.037859    0.394034
# min         -0.102700   0.000000   0.536000   0.000000   -1.000000
# 25%          0.000000   0.000000   1.000000   0.000000    0.000000
# 50%          0.000000   0.000000   1.000000   0.000000    0.000000
# 75%          0.000000   0.000000   1.000000   0.000000    0.000000
# max          0.381800   0.464000   1.000000   0.123000    1.000000
#
#        text_compound   text_pos   text_neu   text_neg  text_sent
# count      20.000000  20.000000  20.000000  20.000000   20.00000
# mean        0.099135   0.043900   0.939900   0.016200    0.15000
# std         0.305228   0.065594   0.068112   0.029573    0.74516
# min        -0.381800   0.000000   0.791000   0.000000   -1.00000
# 25%         0.000000   0.000000   0.891750   0.000000    0.00000
# 50%         0.000000   0.000000   0.957000   0.000000    0.00000
# 75%         0.463275   0.108250   1.000000   0.010750    1.00000
# max         0.571900   0.158000   1.000000   0.080000    1.00000

# %%
# Describe the Ethereum Sentiment
# Following the same as above:

# First I need to get the sentiment calculation
def get_sentiment(score):
    """
    Calculates the sentiment based on the compound score.
    """
    result = 0  # Neutral by default
    if score >= 0.05:  # Positive
        result = 1
    elif score <= -0.05:  # Negative
        result = -1

    return result

# %%
# Second I need the Sentiment scores dictionaries
title_sent = {
    "title_compound": [],
    "title_pos": [],
    "title_neu": [],
    "title_neg": [],
    "title_sent": [],
}
text_sent = {
    "text_compound": [],
    "text_pos": [],
    "text_neu": [],
    "text_neg": [],
    "text_sent": [],
}

# Get sentiment for the text and the title
for index, row in ethereum_df.iterrows():
    try:
        # Sentiment scoring with VADER
        title_sentiment = analyzer.polarity_scores(row["title"])
        title_sent["title_compound"].append(title_sentiment["compound"])
        title_sent["title_pos"].append(title_sentiment["pos"])
        title_sent["title_neu"].append(title_sentiment["neu"])
        title_sent["title_neg"].append(title_sentiment["neg"])
        title_sent["title_sent"].append(get_sentiment(title_sentiment["compound"]))

        text_sentiment = analyzer.polarity_scores(row["text"])
        text_sent["text_compound"].append(text_sentiment["compound"])
        text_sent["text_pos"].append(text_sentiment["pos"])
        text_sent["text_neu"].append(text_sentiment["neu"])
        text_sent["text_neg"].append(text_sentiment["neg"])
        text_sent["text_sent"].append(get_sentiment(text_sentiment["compound"]))
    except AttributeError:
        pass

# Attaching sentiment columns to the Bitcoin DataFrame
title_sentiment_df = pd.DataFrame(title_sent)
text_sentiment_df = pd.DataFrame(text_sent)
ethereum_df = ethereum_df.join(title_sentiment_df).join(text_sentiment_df)

ethereum_df.head()
# Out:
#                                                title  \
# 0  The NFT Bay asks if you would steal all the JPEGs
# 1  Almost buying a copy of the Constitution is ea...
# 2                        AMC Begins Accepting Crypto
# 3    What’s Ethereum and Is It Worth the Investment?
# 4  A Software Bug Let Hackers Drain $31M From a C...
#
#                                          description  \
# 0  The NFT Bay is an incredible piece of performa...
# 1  ConstitutionDAO has refunded more than half of...
# 2  Bitcoin, Ethereum, Bitcoin Cash and Litecoin a...
# 3  Ethereum has been on a tear this year. It’s ou...
# 4  An attacker exploited a vulnerability in MonoX...
#
#                                                 text        date language  \
# 0  If you claim ownership, someone will probably ...  2021-11-19       en
# 1  More than $1.2 million has already been spent ...  2021-11-24       en
# 2  In keeping with a previous announcement, AMC t...  2021-11-12       en
# 3  Ethereum has been on a tear this year. Its out...  2021-11-23       en
# 4  Blockchain startup MonoX Finance said on Wedne...  2021-12-02       en
#
#    title_compound  title_pos  title_neu  title_neg  title_sent  text_compound  \
# 0         -0.4939      0.000      0.758      0.242          -1         0.7783
# 1          0.5346      0.271      0.643      0.086           1         0.0000
# 2          0.3818      0.464      0.536      0.000           1         0.5719
# 3          0.2263      0.213      0.787      0.000           1         0.6542
# 4          0.0000      0.000      1.000      0.000           0        -0.0516
#
#    text_pos  text_neu  text_neg  text_sent
# 0     0.216     0.784     0.000          1
# 1     0.000     1.000     0.000          0
# 2     0.153     0.847     0.000          1
# 3     0.178     0.822     0.000          1
# 4     0.074     0.847     0.079         -1

# %%
# Now to analyze the results:
ethereum_df.plot(
    y=["title_sent", "text_sent"],
    kind="bar",
    title="News Title and Text Sentiment Comparison",
    figsize=(10, 8),
    grid=True,
)
# Out:
# <AxesSubplot:title={'center':'News Title and Text Sentiment Comparison'}>

# %%
ethereum_df.describe()
# Out:
#        title_compound  title_pos  title_neu  title_neg  title_sent  \
# count       20.000000  20.000000  20.000000  20.000000    20.00000
# mean         0.088340   0.116100   0.828400   0.055500     0.25000
# std          0.267503   0.165103   0.208207   0.093307     0.71635
# min         -0.493900   0.000000   0.342000   0.000000    -1.00000
# 25%          0.000000   0.000000   0.761750   0.000000     0.00000
# 50%          0.000000   0.000000   0.862000   0.000000     0.00000
# 75%          0.243725   0.197250   1.000000   0.095250     1.00000
# max          0.534600   0.466000   1.000000   0.242000     1.00000
#
#        text_compound   text_pos   text_neu  text_neg  text_sent
# count      20.000000  20.000000  20.000000  20.00000  20.000000
# mean        0.250890   0.084150   0.889550   0.02620   0.500000
# std         0.316803   0.070344   0.079778   0.03871   0.760886
# min        -0.318200   0.000000   0.729000   0.00000  -1.000000
# 25%         0.000000   0.032250   0.831750   0.00000   0.000000
# 50%         0.248950   0.075000   0.910500   0.00000   1.000000
# 75%         0.429075   0.121500   0.945250   0.06200   1.000000
# max         0.817600   0.221000   1.000000   0.11500   1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Ethereum had the highest mean for text positive scores at 0.08415 vs Bitcoin at 0.04390.
#
# Q: Which coin had the highest compound score?
#
# A: Ethereum had the highest mean for compound score at 0.250890 vs Bitcoin at 0.099135; and the max text compound score was 0.81760 for Ethereum.
#
# Q. Which coin had the highest positive score?
#
# A: Ethereum had the highest (max) positive score at 0.2210.

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()

article = bitcoin_news
print(article)
# Out:
# {'status': 'ok', 'totalResults': 8025, 'articles': [{'source': {'id': None, 'name': 'New York Times'}, 'author': 'Corey Kilgannon', 'title': 'Why New York State Is Experiencing a Bitcoin Boom', 'description': 'Cryptocurrency miners are flocking to New York’s faded industrial towns, prompting concern over the environmental impact of huge computer farms.', 'url': 'https://www.nytimes.com/2021/12/05/nyregion/bitcoin-mining-upstate-new-york.html', 'urlToImage': 'https://static01.nyt.com/images/2021/11/25/nyregion/00nybitcoin5/00nybitcoin5-facebookJumbo.jpg', 'publishedAt': '2021-12-06T00:42:28Z', 'content': 'The plant opening northeast of Niagara Falls this month, in Somerset, N.Y., is part of a $550 million project by Terawulf, a Bitcoin mining company. The project also includes a proposed 150-megawatt … [+1514 chars]'}, {'source': {'id': 'engadget', 'name': 'Engadget'}, 'author': 'Steve Dent', 'title': "Nothing's 'Black Edition' brings a modern touch to its funky Ear 1 buds", 'description': 'Earlier this year, Nothing released a pair of relatively cheap $99 Ear 1 earbuds with a fun transparent case, wireless charging and decent sound quality. Now, the company (created by OnePlus cofounder Carl Pei) has unveiled the new Ear 1 "Black Edition" that …', 'url': 'https://www.engadget.com/nothing-unveils-a-black-edition-of-its-ear-1-wireless-buds-144518774.html', 'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2021-12/722a9000-52ab-11ec-962a-b075b43f57f3', 'publishedAt': '2021-12-01T14:45:18Z', 'content': 'Earlier this year, Nothing released a pair of relatively cheap $99 Ear 1 earbuds with a fun transparent case, wireless charging and decent sound quality. Now, the company (created by OnePlus cofounde… [+1395 chars]'}, {'source': {'id': 'reuters', 'name': 'Reuters'}, 'author': None, 'title': "Explainer: What we know so far about El Salvador's volcano-powered bitcoin bond - Reuters", 'description': 'El Salvador plans to build the world\'s first <a href="https://www.reuters.com/markets/rates-bonds/el-salvador-plans-first-bitcoin-city-backed-by-bitcoin-bonds-2021-11-21" target="_blank">"Bitcoin City"</a> with money from a $1 billion bitcoin-backed bond the …', 'url': 'https://www.reuters.com/markets/us/what-we-know-so-far-about-el-salvadors-volcano-powered-bitcoin-bond-2021-11-22/', 'urlToImage': 'https://www.reuters.com/pf/resources/images/reuters/reuters-default.png?d=59', 'publishedAt': '2021-11-22T23:35:00Z', 'content': 'MIZATA, El Salvador/LONDON, Nov 22 (Reuters) - El Salvador plans to build the world\'s first "Bitcoin City" with money from a $1 billion bitcoin-backed bond the country\'s President Nayib Bukele said o… [+3147 chars]'}, {'source': {'id': None, 'name': 'Entrepreneur'}, 'author': 'Entrepreneur Staff', 'title': 'AMC Begins Accepting Crypto', 'description': 'Bitcoin, Ethereum, Bitcoin Cash and Litecoin are accepted.', 'url': 'https://www.entrepreneur.com/article/396981', 'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1636738243-GettyImages-1307671673.jpg', 'publishedAt': '2021-11-12T17:31:23Z', 'content': 'In keeping with a previous announcement, AMC theaters now accept cryptocurrencies as payment for online purchases.\xa0\r\nBitcoin, Ethereum, Bitcoin Cash and Litecoin are accepted.\xa0\r\nPreviously, the compa… [+1036 chars]'}, {'source': {'id': 'reuters', 'name': 'Reuters'}, 'author': 'Reuters Editorial', 'title': "El Salvador plans 'Bitcoin City' - Reuters", 'description': "After becoming the first country to accept the cryptocurrency as legal tender, El Salvador plans to build the world's first Bitcoin City, funded initially by bitcoin-backed bonds.", 'url': 'https://www.reuters.com/video/watch/idPEH4?now=true', 'urlToImage': 'https://ajo.prod.reuters.tv/api/v2/img/619b824be4b085d396fd1eb4-1637581387726?location=LANDSCAPE', 'publishedAt': '2021-11-22T12:01:51Z', 'content': "Posted \r\nAfter becoming the first country to accept the cryptocurrency as legal tender, El Salvador plans to buil ...

# %%
article2 = ethereum_news
print(article2)

# Create a list of stopwords
# See below

# Expand the default stopwords list if necessary
# I did not see any to add, but if there were I would use the following code (with example words):
# sw_addons = {'said', 'sent', 'found', 'including', 'today', 'announced', 'week', 'basically', 'also'}
# Out:
# {'status': 'ok', 'totalResults': 3392, 'articles': [{'source': {'id': 'the-verge', 'name': 'The Verge'}, 'author': 'Mitchell Clark', 'title': 'The NFT Bay asks if you would steal all the JPEGs', 'description': 'The NFT Bay is an incredible piece of performance art that promises to let you download all the NFTs on the Ethereum blockchain. The torrent contains nearly 20TB worth of files, and works as a commentary on collecting and owning.', 'url': 'https://www.theverge.com/2021/11/18/22790131/nft-bay-pirating-digital-ownership-piracy-crypto-art-right-click', 'urlToImage': 'https://cdn.vox-cdn.com/thumbor/UMHdxnP0BlxxYxbIu9Ea5K1QwGk=/0x0:2028x1062/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/23025815/Screen_Shot_2021_11_18_at_14.21.58.png', 'publishedAt': '2021-11-19T02:01:07Z', 'content': 'If you claim ownership, someone will probably want to take it\r\nIn what may be one of the better pieces of performance art this year, Australian Geoffrey Huntley has created a website that promises to… [+4542 chars]'}, {'source': {'id': 'the-verge', 'name': 'The Verge'}, 'author': 'Jacob Kastrenakes', 'title': 'Almost buying a copy of the Constitution is easy, but giving the money back is hard', 'description': 'ConstitutionDAO has refunded more than half of the contributions to its failed attempt to buy a rare copy of the US Constitution at auction. But high gas fees have cost more than $1.2 million so far.', 'url': 'https://www.theverge.com/2021/11/24/22800995/constitutiondao-refund-progress-steep-gas-fees-cryptocurrency', 'urlToImage': 'https://cdn.vox-cdn.com/thumbor/saEc_B14EZIKIVPp0q8KT-zxPlU=/0x125:1746x1039/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/23022988/constdao.jpg', 'publishedAt': '2021-11-24T23:00:34Z', 'content': 'More than $1.2 million has already been spent on gas fees\r\nOne of 13 remaining copies of the Official Edition of the Constitution.\r\nImage: Sothebys\r\nAs of last Thursday night, ConstitutionDAO found i… [+5262 chars]'}, {'source': {'id': None, 'name': 'Entrepreneur'}, 'author': 'Entrepreneur Staff', 'title': 'AMC Begins Accepting Crypto', 'description': 'Bitcoin, Ethereum, Bitcoin Cash and Litecoin are accepted.', 'url': 'https://www.entrepreneur.com/article/396981', 'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1636738243-GettyImages-1307671673.jpg', 'publishedAt': '2021-11-12T17:31:23Z', 'content': 'In keeping with a previous announcement, AMC theaters now accept cryptocurrencies as payment for online purchases.\xa0\r\nBitcoin, Ethereum, Bitcoin Cash and Litecoin are accepted.\xa0\r\nPreviously, the compa… [+1036 chars]'}, {'source': {'id': None, 'name': 'Due.com'}, 'author': 'John Rampton', 'title': 'What’s Ethereum and Is It Worth the Investment?', 'description': 'Ethereum has been on a tear this year. It’s outperformed bitcoin this year and has hit an all-time high. Ethereum has even won over people like Mark Cuban. “I have...', 'url': 'https://due.com/blog/whats-ethereum-and-is-it-worth-the-investment/', 'urlToImage': 'https://assets.entrepreneur.com/providers/due/hero-image-due-398724.jpeg', 'publishedAt': '2021-11-23T14:00:09Z', 'content': 'Ethereum has been on a tear this year. Its outperformed bitcoin this year and has hit an all-time high. Ethereum has even won over people like Mark Cuban.\r\nI have my fair share of bitcoin, but Im mor… [+10978 chars]'}, {'source': {'id': 'wired', 'name': 'Wired'}, 'author': 'Dan Goodin, Ars Technica', 'title': 'A Software Bug Let Hackers Drain $31M From a Crypto Service', 'description': "An attacker exploited a vulnerability in MonoX Finance's smart contract to inflate the price of its digital token and then cash out.", 'url': 'https://www.wired.com/story/hackers-drain-31-million-from-crypto-service/', 'urlToImage': 'https://media.wired.com/photos/61a8e032b7391d86bbd9a4c4/191:100/w_1280,c_limit/Sec_ars_GettyImages-1324841380.jpg', 'publishedAt': '2021-12-02T23:45:00Z', 'content': 'Blockchain startup MonoX Finance said on W ...

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Create a list of the words
    words = word_tokenize(text)

    # Convert the words to lowercase
    words = list(filter(lambda w: w.lower(), words))
    
    # Remove the punctuation
    words = list(filter(lambda t: t not in punctuation, words))
    
    # Remove the stopwords
    # words = list(filter(lambda t: t.lower() not in stop, words))
    # There are none I removed
    
    # Lemmatize Words into root words
    tokens = [lemmatizer.lemmatize(word) for word in words]
    
    return tokens

# Create a new tokens column for Bitcoin
bitcoin_df["tokens"] = bitcoin_df.text.apply(tokenizer)
bitcoin_df.head()
# Out:
#                                                title  \
# 0  Why New York State Is Experiencing a Bitcoin Boom
# 1  Nothing's 'Black Edition' brings a modern touc...
# 2  Explainer: What we know so far about El Salvad...
# 3                        AMC Begins Accepting Crypto
# 4         El Salvador plans 'Bitcoin City' - Reuters
#
#                                          description  \
# 0  Cryptocurrency miners are flocking to New York...
# 1  Earlier this year, Nothing released a pair of ...
# 2  El Salvador plans to build the world's first <...
# 3  Bitcoin, Ethereum, Bitcoin Cash and Litecoin a...
# 4  After becoming the first country to accept the...
#
#                                                 text        date language  \
# 0  The plant opening northeast of Niagara Falls t...  2021-12-06       en
# 1  Earlier this year, Nothing released a pair of ...  2021-12-01       en
# 2  MIZATA, El Salvador/LONDON, Nov 22 (Reuters) -...  2021-11-22       en
# 3  In keeping with a previous announcement, AMC t...  2021-11-12       en
# 4  Posted \r\nAfter becoming the first country to...  2021-11-22       en
#
#    title_compound  title_pos  title_neu  title_neg  title_sent  text_compound  \
# 0          0.0000      0.000      1.000      0.000           0         0.0000
# 1         -0.1027      0.000      0.877      0.123          -1         0.5106
# 2          0.0000      0.000      1.000      0.000           0         0.0000
# 3          0.3818      0.464      0.536      0.000           1         0.5719
# 4          0.0000      0.000      1.000      0.000           0         0.4767
#
#    text_pos  text_neu  text_neg  text_sent  \
# 0     0.000     1.000       0.0          0
# 1     0.099     0.901       0.0          1
# 2     0.000     1.000       0.0          0
# 3     0.153     0.847       0.0          1
# 4     0.136     0.864       0.0          1
#
#                                               tokens
# 0  [The, plant, opening, northeast, of, Niagara, ...
# 1  [Earlier, this, year, Nothing, released, a, pa...
# 2  [MIZATA, El, Salvador/LONDON, Nov, 22, Reuters...
# 3  [In, keeping, with, a, previous, announcement,...
# 4  [Posted, After, becoming, the, first, country,...

# %% [raw]
# For reference - another example code similiar:
# def process_text(article):
#     sw = set(stopwords.words('english'))
#     regex = re.compile("[^a-zA-Z ]")
#     re_clean = regex.sub('', bitcoin_news)
#     words = word_tokenize(re_clean)
#     lem = [lemmatizer.lemmatize(word) for word in words]
#     output = [word.lower() for word in words if word.lower() not in sw]
#     return output

# %%
# Now to do Ethereum - same process as above
ethereum_df["tokens"] = ethereum_df.text.apply(tokenizer)
ethereum_df.head()
# Out:
#                                                title  \
# 0  The NFT Bay asks if you would steal all the JPEGs
# 1  Almost buying a copy of the Constitution is ea...
# 2                        AMC Begins Accepting Crypto
# 3    What’s Ethereum and Is It Worth the Investment?
# 4  A Software Bug Let Hackers Drain $31M From a C...
#
#                                          description  \
# 0  The NFT Bay is an incredible piece of performa...
# 1  ConstitutionDAO has refunded more than half of...
# 2  Bitcoin, Ethereum, Bitcoin Cash and Litecoin a...
# 3  Ethereum has been on a tear this year. It’s ou...
# 4  An attacker exploited a vulnerability in MonoX...
#
#                                                 text        date language  \
# 0  If you claim ownership, someone will probably ...  2021-11-19       en
# 1  More than $1.2 million has already been spent ...  2021-11-24       en
# 2  In keeping with a previous announcement, AMC t...  2021-11-12       en
# 3  Ethereum has been on a tear this year. Its out...  2021-11-23       en
# 4  Blockchain startup MonoX Finance said on Wedne...  2021-12-02       en
#
#    title_compound  title_pos  title_neu  title_neg  title_sent  text_compound  \
# 0         -0.4939      0.000      0.758      0.242          -1         0.7783
# 1          0.5346      0.271      0.643      0.086           1         0.0000
# 2          0.3818      0.464      0.536      0.000           1         0.5719
# 3          0.2263      0.213      0.787      0.000           1         0.6542
# 4          0.0000      0.000      1.000      0.000           0        -0.0516
#
#    text_pos  text_neu  text_neg  text_sent  \
# 0     0.216     0.784     0.000          1
# 1     0.000     1.000     0.000          0
# 2     0.153     0.847     0.000          1
# 3     0.178     0.822     0.000          1
# 4     0.074     0.847     0.079         -1
#
#                                               tokens
# 0  [If, you, claim, ownership, someone, will, pro...
# 1  [More, than, 1.2, million, ha, already, been, ...
# 2  [In, keeping, with, a, previous, announcement,...
# 3  [Ethereum, ha, been, on, a, tear, this, year, ...
# 4  [Blockchain, startup, MonoX, Finance, said, on...

# %%
# Create a new tokens column for Bitcoin
# Completed above.

# %%
# Create a new tokens column for Ethereum
# Completed above.

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
# Generate the Bitcoin N-grams where N=2
def process_text(article):
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', str(bitcoin_news))
    words = word_tokenize(re_clean)
    lem = [lemmatizer.lemmatize(word) for word in words]
    output = [word.lower() for word in words if word.lower() not in sw]
    return output

# %%
processed = process_text(article)
print(processed)
# Out:
# ['status', 'ok', 'totalresults', 'articles', 'source', 'id', 'none', 'name', 'new', 'york', 'times', 'author', 'corey', 'kilgannon', 'title', 'new', 'york', 'state', 'experiencing', 'bitcoin', 'boom', 'description', 'cryptocurrency', 'miners', 'flocking', 'new', 'yorks', 'faded', 'industrial', 'towns', 'prompting', 'concern', 'environmental', 'impact', 'huge', 'computer', 'farms', 'url', 'httpswwwnytimescomnyregionbitcoinminingupstatenewyorkhtml', 'urltoimage', 'httpsstaticnytcomimagesnyregionnybitcoinnybitcoinfacebookjumbojpg', 'publishedat', 'tz', 'content', 'plant', 'opening', 'northeast', 'niagara', 'falls', 'month', 'somerset', 'ny', 'part', 'million', 'project', 'terawulf', 'bitcoin', 'mining', 'company', 'project', 'also', 'includes', 'proposed', 'megawatt', 'chars', 'source', 'id', 'engadget', 'name', 'engadget', 'author', 'steve', 'dent', 'title', 'nothings', 'black', 'edition', 'brings', 'modern', 'touch', 'funky', 'ear', 'buds', 'description', 'earlier', 'year', 'nothing', 'released', 'pair', 'relatively', 'cheap', 'ear', 'earbuds', 'fun', 'transparent', 'case', 'wireless', 'charging', 'decent', 'sound', 'quality', 'company', 'created', 'oneplus', 'cofounder', 'carl', 'pei', 'unveiled', 'new', 'ear', 'black', 'edition', 'url', 'httpswwwengadgetcomnothingunveilsablackeditionofitsearwirelessbudshtml', 'urltoimage', 'httpssyimgcomoscreatruploadedimagesaabecabbff', 'publishedat', 'tz', 'content', 'earlier', 'year', 'nothing', 'released', 'pair', 'relatively', 'cheap', 'ear', 'earbuds', 'fun', 'transparent', 'case', 'wireless', 'charging', 'decent', 'sound', 'quality', 'company', 'created', 'oneplus', 'cofounde', 'chars', 'source', 'id', 'reuters', 'name', 'reuters', 'author', 'none', 'title', 'explainer', 'know', 'far', 'el', 'salvadors', 'volcanopowered', 'bitcoin', 'bond', 'reuters', 'description', 'el', 'salvador', 'plans', 'build', 'worlds', 'first', 'hrefhttpswwwreuterscommarketsratesbondselsalvadorplansfirstbitcoincitybackedbybitcoinbonds', 'targetblankbitcoin', 'citya', 'money', 'billion', 'bitcoinbacked', 'bond', 'url', 'httpswwwreuterscommarketsuswhatweknowsofaraboutelsalvadorsvolcanopoweredbitcoinbond', 'urltoimage', 'httpswwwreuterscompfresourcesimagesreutersreutersdefaultpngd', 'publishedat', 'tz', 'content', 'mizata', 'el', 'salvadorlondon', 'nov', 'reuters', 'el', 'salvador', 'plans', 'build', 'worlds', 'first', 'bitcoin', 'city', 'money', 'billion', 'bitcoinbacked', 'bond', 'countrys', 'president', 'nayib', 'bukele', 'said', 'chars', 'source', 'id', 'none', 'name', 'entrepreneur', 'author', 'entrepreneur', 'staff', 'title', 'amc', 'begins', 'accepting', 'crypto', 'description', 'bitcoin', 'ethereum', 'bitcoin', 'cash', 'litecoin', 'accepted', 'url', 'httpswwwentrepreneurcomarticle', 'urltoimage', 'httpsassetsentrepreneurcomcontentxgettyimagesjpg', 'publishedat', 'tz', 'content', 'keeping', 'previous', 'announcement', 'amc', 'theaters', 'accept', 'cryptocurrencies', 'payment', 'online', 'purchasesxarnbitcoin', 'ethereum', 'bitcoin', 'cash', 'litecoin', 'acceptedxarnpreviously', 'compa', 'chars', 'source', 'id', 'reuters', 'name', 'reuters', 'author', 'reuters', 'editorial', 'title', 'el', 'salvador', 'plans', 'bitcoin', 'city', 'reuters', 'description', 'becoming', 'first', 'country', 'accept', 'cryptocurrency', 'legal', 'tender', 'el', 'salvador', 'plans', 'build', 'worlds', 'first', 'bitcoin', 'city', 'funded', 'initially', 'bitcoinbacked', 'bonds', 'url', 'httpswwwreuterscomvideowatchidpehnowtrue', 'urltoimage', 'httpsajoprodreuterstvapivimgbbebdfdeblocationlandscape', 'publishedat', 'tz', 'content', 'posted', 'rnafter', 'becoming', 'first', 'country', 'accept', 'cryptocurrency', 'legal', 'tender', 'el', 'salvador', 'plans', 'build', 'worlds', 'first', 'bitcoin', 'city', 'funded', 'initially', 'bitcoinbacked', 'bonds', 'source', 'id', 'theverge', 'name', 'verge', 'author', 'jon', 'porter', 'title', 'nothings', 'debut', 'earbuds', 'come', 'black', 'description', 'nothings', 'ear', 'earbuds', 'soon', 'com ...

# %%
bitcoin_bigram_counts = Counter(ngrams(processed, n=2))
print(dict(bitcoin_bigram_counts))
# Out:
# {('status', 'ok'): 1, ('ok', 'totalresults'): 1, ('totalresults', 'articles'): 1, ('articles', 'source'): 1, ('source', 'id'): 20, ('id', 'none'): 4, ('none', 'name'): 4, ('name', 'new'): 1, ('new', 'york'): 2, ('york', 'times'): 1, ('times', 'author'): 1, ('author', 'corey'): 1, ('corey', 'kilgannon'): 1, ('kilgannon', 'title'): 1, ('title', 'new'): 1, ('york', 'state'): 1, ('state', 'experiencing'): 1, ('experiencing', 'bitcoin'): 1, ('bitcoin', 'boom'): 1, ('boom', 'description'): 1, ('description', 'cryptocurrency'): 1, ('cryptocurrency', 'miners'): 1, ('miners', 'flocking'): 1, ('flocking', 'new'): 1, ('new', 'yorks'): 1, ('yorks', 'faded'): 1, ('faded', 'industrial'): 1, ('industrial', 'towns'): 1, ('towns', 'prompting'): 1, ('prompting', 'concern'): 1, ('concern', 'environmental'): 1, ('environmental', 'impact'): 1, ('impact', 'huge'): 1, ('huge', 'computer'): 1, ('computer', 'farms'): 1, ('farms', 'url'): 1, ('url', 'httpswwwnytimescomnyregionbitcoinminingupstatenewyorkhtml'): 1, ('httpswwwnytimescomnyregionbitcoinminingupstatenewyorkhtml', 'urltoimage'): 1, ('urltoimage', 'httpsstaticnytcomimagesnyregionnybitcoinnybitcoinfacebookjumbojpg'): 1, ('httpsstaticnytcomimagesnyregionnybitcoinnybitcoinfacebookjumbojpg', 'publishedat'): 1, ('publishedat', 'tz'): 20, ('tz', 'content'): 20, ('content', 'plant'): 1, ('plant', 'opening'): 1, ('opening', 'northeast'): 1, ('northeast', 'niagara'): 1, ('niagara', 'falls'): 1, ('falls', 'month'): 1, ('month', 'somerset'): 1, ('somerset', 'ny'): 1, ('ny', 'part'): 1, ('part', 'million'): 1, ('million', 'project'): 1, ('project', 'terawulf'): 1, ('terawulf', 'bitcoin'): 1, ('bitcoin', 'mining'): 1, ('mining', 'company'): 1, ('company', 'project'): 1, ('project', 'also'): 1, ('also', 'includes'): 1, ('includes', 'proposed'): 1, ('proposed', 'megawatt'): 1, ('megawatt', 'chars'): 1, ('chars', 'source'): 17, ('id', 'engadget'): 2, ('engadget', 'name'): 2, ('name', 'engadget'): 2, ('engadget', 'author'): 2, ('author', 'steve'): 1, ('steve', 'dent'): 1, ('dent', 'title'): 1, ('title', 'nothings'): 2, ('nothings', 'black'): 1, ('black', 'edition'): 2, ('edition', 'brings'): 1, ('brings', 'modern'): 1, ('modern', 'touch'): 1, ('touch', 'funky'): 1, ('funky', 'ear'): 1, ('ear', 'buds'): 1, ('buds', 'description'): 1, ('description', 'earlier'): 1, ('earlier', 'year'): 3, ('year', 'nothing'): 2, ('nothing', 'released'): 2, ('released', 'pair'): 2, ('pair', 'relatively'): 2, ('relatively', 'cheap'): 2, ('cheap', 'ear'): 2, ('ear', 'earbuds'): 5, ('earbuds', 'fun'): 2, ('fun', 'transparent'): 2, ('transparent', 'case'): 2, ('case', 'wireless'): 2, ('wireless', 'charging'): 2, ('charging', 'decent'): 2, ('decent', 'sound'): 2, ('sound', 'quality'): 2, ('quality', 'company'): 2, ('company', 'created'): 2, ('created', 'oneplus'): 2, ('oneplus', 'cofounder'): 1, ('cofounder', 'carl'): 1, ('carl', 'pei'): 1, ('pei', 'unveiled'): 1, ('unveiled', 'new'): 1, ('new', 'ear'): 1, ('ear', 'black'): 1, ('edition', 'url'): 1, ('url', 'httpswwwengadgetcomnothingunveilsablackeditionofitsearwirelessbudshtml'): 1, ('httpswwwengadgetcomnothingunveilsablackeditionofitsearwirelessbudshtml', 'urltoimage'): 1, ('urltoimage', 'httpssyimgcomoscreatruploadedimagesaabecabbff'): 1, ('httpssyimgcomoscreatruploadedimagesaabecabbff', 'publishedat'): 1, ('content', 'earlier'): 1, ('oneplus', 'cofounde'): 1, ('cofounde', 'chars'): 1, ('id', 'reuters'): 12, ('reuters', 'name'): 12, ('name', 'reuters'): 12, ('reuters', 'author'): 12, ('author', 'none'): 4, ('none', 'title'): 4, ('title', 'explainer'): 2, ('explainer', 'know'): 2, ('know', 'far'): 1, ('far', 'el'): 1, ('el', 'salvadors'): 2, ('salvadors', 'volcanopowered'): 1, ('volcanopowered', 'bitcoin'): 1, ('bitcoin', 'bond'): 2, ('bond', 'reuters'): 1, ('reuters', 'description'): 6, ('description', 'el'): 2, ('el', 'salvador'): 6, ('salvador', 'plans'): 7, ('plans', 'build'): 6, ('build', 'worlds'): 6, ('worlds', 'first'): 6, ('first', 'hrefhttpswwwreuterscommarketsratesbondsel ...

# %%
# Generate the Ethereum N-grams where N=2
processed2 = process_text(article2)
print(processed2)

ethereum_bigram_counts = Counter(ngrams(processed2, n=2))
print(dict(ethereum_bigram_counts))
# Out:
# ['status', 'ok', 'totalresults', 'articles', 'source', 'id', 'none', 'name', 'new', 'york', 'times', 'author', 'corey', 'kilgannon', 'title', 'new', 'york', 'state', 'experiencing', 'bitcoin', 'boom', 'description', 'cryptocurrency', 'miners', 'flocking', 'new', 'yorks', 'faded', 'industrial', 'towns', 'prompting', 'concern', 'environmental', 'impact', 'huge', 'computer', 'farms', 'url', 'httpswwwnytimescomnyregionbitcoinminingupstatenewyorkhtml', 'urltoimage', 'httpsstaticnytcomimagesnyregionnybitcoinnybitcoinfacebookjumbojpg', 'publishedat', 'tz', 'content', 'plant', 'opening', 'northeast', 'niagara', 'falls', 'month', 'somerset', 'ny', 'part', 'million', 'project', 'terawulf', 'bitcoin', 'mining', 'company', 'project', 'also', 'includes', 'proposed', 'megawatt', 'chars', 'source', 'id', 'engadget', 'name', 'engadget', 'author', 'steve', 'dent', 'title', 'nothings', 'black', 'edition', 'brings', 'modern', 'touch', 'funky', 'ear', 'buds', 'description', 'earlier', 'year', 'nothing', 'released', 'pair', 'relatively', 'cheap', 'ear', 'earbuds', 'fun', 'transparent', 'case', 'wireless', 'charging', 'decent', 'sound', 'quality', 'company', 'created', 'oneplus', 'cofounder', 'carl', 'pei', 'unveiled', 'new', 'ear', 'black', 'edition', 'url', 'httpswwwengadgetcomnothingunveilsablackeditionofitsearwirelessbudshtml', 'urltoimage', 'httpssyimgcomoscreatruploadedimagesaabecabbff', 'publishedat', 'tz', 'content', 'earlier', 'year', 'nothing', 'released', 'pair', 'relatively', 'cheap', 'ear', 'earbuds', 'fun', 'transparent', 'case', 'wireless', 'charging', 'decent', 'sound', 'quality', 'company', 'created', 'oneplus', 'cofounde', 'chars', 'source', 'id', 'reuters', 'name', 'reuters', 'author', 'none', 'title', 'explainer', 'know', 'far', 'el', 'salvadors', 'volcanopowered', 'bitcoin', 'bond', 'reuters', 'description', 'el', 'salvador', 'plans', 'build', 'worlds', 'first', 'hrefhttpswwwreuterscommarketsratesbondselsalvadorplansfirstbitcoincitybackedbybitcoinbonds', 'targetblankbitcoin', 'citya', 'money', 'billion', 'bitcoinbacked', 'bond', 'url', 'httpswwwreuterscommarketsuswhatweknowsofaraboutelsalvadorsvolcanopoweredbitcoinbond', 'urltoimage', 'httpswwwreuterscompfresourcesimagesreutersreutersdefaultpngd', 'publishedat', 'tz', 'content', 'mizata', 'el', 'salvadorlondon', 'nov', 'reuters', 'el', 'salvador', 'plans', 'build', 'worlds', 'first', 'bitcoin', 'city', 'money', 'billion', 'bitcoinbacked', 'bond', 'countrys', 'president', 'nayib', 'bukele', 'said', 'chars', 'source', 'id', 'none', 'name', 'entrepreneur', 'author', 'entrepreneur', 'staff', 'title', 'amc', 'begins', 'accepting', 'crypto', 'description', 'bitcoin', 'ethereum', 'bitcoin', 'cash', 'litecoin', 'accepted', 'url', 'httpswwwentrepreneurcomarticle', 'urltoimage', 'httpsassetsentrepreneurcomcontentxgettyimagesjpg', 'publishedat', 'tz', 'content', 'keeping', 'previous', 'announcement', 'amc', 'theaters', 'accept', 'cryptocurrencies', 'payment', 'online', 'purchasesxarnbitcoin', 'ethereum', 'bitcoin', 'cash', 'litecoin', 'acceptedxarnpreviously', 'compa', 'chars', 'source', 'id', 'reuters', 'name', 'reuters', 'author', 'reuters', 'editorial', 'title', 'el', 'salvador', 'plans', 'bitcoin', 'city', 'reuters', 'description', 'becoming', 'first', 'country', 'accept', 'cryptocurrency', 'legal', 'tender', 'el', 'salvador', 'plans', 'build', 'worlds', 'first', 'bitcoin', 'city', 'funded', 'initially', 'bitcoinbacked', 'bonds', 'url', 'httpswwwreuterscomvideowatchidpehnowtrue', 'urltoimage', 'httpsajoprodreuterstvapivimgbbebdfdeblocationlandscape', 'publishedat', 'tz', 'content', 'posted', 'rnafter', 'becoming', 'first', 'country', 'accept', 'cryptocurrency', 'legal', 'tender', 'el', 'salvador', 'plans', 'build', 'worlds', 'first', 'bitcoin', 'city', 'funded', 'initially', 'bitcoinbacked', 'bonds', 'source', 'id', 'theverge', 'name', 'verge', 'author', 'jon', 'porter', 'title', 'nothings', 'debut', 'earbuds', 'come', 'black', 'description', 'nothings', 'ear', 'earbuds', 'soon', 'com ...
# {('status', 'ok'): 1, ('ok', 'totalresults'): 1, ('totalresults', 'articles'): 1, ('articles', 'source'): 1, ('source', 'id'): 20, ('id', 'none'): 4, ('none', 'name'): 4, ('name', 'new'): 1, ('new', 'york'): 2, ('york', 'times'): 1, ('times', 'author'): 1, ('author', 'corey'): 1, ('corey', 'kilgannon'): 1, ('kilgannon', 'title'): 1, ('title', 'new'): 1, ('york', 'state'): 1, ('state', 'experiencing'): 1, ('experiencing', 'bitcoin'): 1, ('bitcoin', 'boom'): 1, ('boom', 'description'): 1, ('description', 'cryptocurrency'): 1, ('cryptocurrency', 'miners'): 1, ('miners', 'flocking'): 1, ('flocking', 'new'): 1, ('new', 'yorks'): 1, ('yorks', 'faded'): 1, ('faded', 'industrial'): 1, ('industrial', 'towns'): 1, ('towns', 'prompting'): 1, ('prompting', 'concern'): 1, ('concern', 'environmental'): 1, ('environmental', 'impact'): 1, ('impact', 'huge'): 1, ('huge', 'computer'): 1, ('computer', 'farms'): 1, ('farms', 'url'): 1, ('url', 'httpswwwnytimescomnyregionbitcoinminingupstatenewyorkhtml'): 1, ('httpswwwnytimescomnyregionbitcoinminingupstatenewyorkhtml', 'urltoimage'): 1, ('urltoimage', 'httpsstaticnytcomimagesnyregionnybitcoinnybitcoinfacebookjumbojpg'): 1, ('httpsstaticnytcomimagesnyregionnybitcoinnybitcoinfacebookjumbojpg', 'publishedat'): 1, ('publishedat', 'tz'): 20, ('tz', 'content'): 20, ('content', 'plant'): 1, ('plant', 'opening'): 1, ('opening', 'northeast'): 1, ('northeast', 'niagara'): 1, ('niagara', 'falls'): 1, ('falls', 'month'): 1, ('month', 'somerset'): 1, ('somerset', 'ny'): 1, ('ny', 'part'): 1, ('part', 'million'): 1, ('million', 'project'): 1, ('project', 'terawulf'): 1, ('terawulf', 'bitcoin'): 1, ('bitcoin', 'mining'): 1, ('mining', 'company'): 1, ('company', 'project'): 1, ('project', 'also'): 1, ('also', 'includes'): 1, ('includes', 'proposed'): 1, ('proposed', 'megawatt'): 1, ('megawatt', 'chars'): 1, ('chars', 'source'): 17, ('id', 'engadget'): 2, ('engadget', 'name'): 2, ('name', 'engadget'): 2, ('engadget', 'author'): 2, ('author', 'steve'): 1, ('steve', 'dent'): 1, ('dent', 'title'): 1, ('title', 'nothings'): 2, ('nothings', 'black'): 1, ('black', 'edition'): 2, ('edition', 'brings'): 1, ('brings', 'modern'): 1, ('modern', 'touch'): 1, ('touch', 'funky'): 1, ('funky', 'ear'): 1, ('ear', 'buds'): 1, ('buds', 'description'): 1, ('description', 'earlier'): 1, ('earlier', 'year'): 3, ('year', 'nothing'): 2, ('nothing', 'released'): 2, ('released', 'pair'): 2, ('pair', 'relatively'): 2, ('relatively', 'cheap'): 2, ('cheap', 'ear'): 2, ('ear', 'earbuds'): 5, ('earbuds', 'fun'): 2, ('fun', 'transparent'): 2, ('transparent', 'case'): 2, ('case', 'wireless'): 2, ('wireless', 'charging'): 2, ('charging', 'decent'): 2, ('decent', 'sound'): 2, ('sound', 'quality'): 2, ('quality', 'company'): 2, ('company', 'created'): 2, ('created', 'oneplus'): 2, ('oneplus', 'cofounder'): 1, ('cofounder', 'carl'): 1, ('carl', 'pei'): 1, ('pei', 'unveiled'): 1, ('unveiled', 'new'): 1, ('new', 'ear'): 1, ('ear', 'black'): 1, ('edition', 'url'): 1, ('url', 'httpswwwengadgetcomnothingunveilsablackeditionofitsearwirelessbudshtml'): 1, ('httpswwwengadgetcomnothingunveilsablackeditionofitsearwirelessbudshtml', 'urltoimage'): 1, ('urltoimage', 'httpssyimgcomoscreatruploadedimagesaabecabbff'): 1, ('httpssyimgcomoscreatruploadedimagesaabecabbff', 'publishedat'): 1, ('content', 'earlier'): 1, ('oneplus', 'cofounde'): 1, ('cofounde', 'chars'): 1, ('id', 'reuters'): 12, ('reuters', 'name'): 12, ('name', 'reuters'): 12, ('reuters', 'author'): 12, ('author', 'none'): 4, ('none', 'title'): 4, ('title', 'explainer'): 2, ('explainer', 'know'): 2, ('know', 'far'): 1, ('far', 'el'): 1, ('el', 'salvadors'): 2, ('salvadors', 'volcanopowered'): 1, ('volcanopowered', 'bitcoin'): 1, ('bitcoin', 'bond'): 2, ('bond', 'reuters'): 1, ('reuters', 'description'): 6, ('description', 'el'): 2, ('el', 'salvador'): 6, ('salvador', 'plans'): 7, ('plans', 'build'): 6, ('build', 'worlds'): 6, ('worlds', 'first'): 6, ('first', 'hrefhttpswwwreuterscommarketsratesbondsel ...

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
print(dict(bitcoin_bigram_counts.most_common(10)))
# Out:
# {('source', 'id'): 20, ('publishedat', 'tz'): 20, ('tz', 'content'): 20, ('chars', 'source'): 17, ('id', 'reuters'): 12, ('reuters', 'name'): 12, ('name', 'reuters'): 12, ('reuters', 'author'): 12, ('salvador', 'plans'): 7, ('reuters', 'description'): 6}

# %%
# Use token_count to get the top 10 words for Ethereum
print(dict(ethereum_bigram_counts.most_common(10)))
# Out:
# {('source', 'id'): 20, ('publishedat', 'tz'): 20, ('tz', 'content'): 20, ('chars', 'source'): 17, ('id', 'reuters'): 12, ('reuters', 'name'): 12, ('name', 'reuters'): 12, ('reuters', 'author'): 12, ('salvador', 'plans'): 7, ('reuters', 'description'): 6}

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
# Generate the Bitcoin word cloud
wc = WordCloud().generate(' '.join(processed))
plt.imshow(wc)

# %%
# Generate the Ethereum word cloud
wc2 = WordCloud().generate(' '.join(processed2))
plt.imshow(wc2)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.2.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.2.0/en_core_web_sm-3.2.0-py3-none-any.whl (13.9 MB)
# Requirement already satisfied: spacy<3.3.0,>=3.2.0 in c:\anaconda3\envs\mlenv\lib\site-packages (from en-core-web-sm==3.2.0) (3.2.0)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in c:\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.10.0.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.7.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: jinja2 in c:\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.11.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.6)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in c:\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.3.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.4.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (4.62.3)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.8.2)
# Requirement already satisfied: pathy>=0.3.5 in c:\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.6.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.0.6)
# Requirement already satisfied: packaging>=20.0 in c:\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (21.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in c:\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.8)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.8.2)
# Requirement already satisfied: numpy>=1.15.0 in c:\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.20.3)
# Requirement already satisfied: setuptools in c:\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (58.0.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\anaconda3\envs\mlenv\lib\site-packages (from spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.26.0)
# Requirement already satisfied: zipp>=0.5 in c:\anaconda3\envs\mlenv\lib\site-packages (from catalogue<2.1.0,>=2.0.6->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\anaconda3\envs\mlenv\lib\site-packages (from packaging>=20.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\anaconda3\envs\mlenv\lib\site-packages (from pathy>=0.3.5->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (5.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\anaconda3\envs\mlenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\anaconda3\envs\mlenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\anaconda3\envs\mlenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\anaconda3\envs\mlenv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (3.1)
# Requirement already satisfied: colorama in c:\anaconda3\envs\mlenv\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (0.4.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\anaconda3\envs\mlenv\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (8.0.3)
# Requirement already satisfied: importlib-metadata in c:\anaconda3\envs\mlenv\lib\site-packages (from click<9.0.0,>=7.1.1->typer<0.5.0,>=0.3.0->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (4.8.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\anaconda3\envs\mlenv\lib\site-packages (from jinja2->spacy<3.3.0,>=3.2.0->en-core-web-sm==3.2.0) (1.1.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together

# %%
# Run the NER processor on all of the text
doc = nlp(bitcoin_news)
doc.ents

# %%
# Add a title to the document
for ent in doc.ents:
    print(ent.text, ent.label_)

# %%
# Render the visualization
displacy.render(doc, style='ent')

# %%
# List all Entities
print([ent.text for ent in doc.ents if ent.label_ == 'GPE'])

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
# YOUR CODE HERE!

# %%
# Run the NER processor on all of the text
# YOUR CODE HERE!

# Add a title to the document
# YOUR CODE HERE!

# %%
# Render the visualization
# YOUR CODE HERE!

# %%
# List all Entities
# YOUR CODE HERE!

# %% [markdown]
# ---
